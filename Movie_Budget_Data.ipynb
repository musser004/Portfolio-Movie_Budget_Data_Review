# %% [markdown]
# # Introduction
#
# Using data scraped from [the-numbers.com](https://www.the-numbers.com/movie/budgets) (up to May 1, 2018), we'll take a look at whether or not there's a relationship between higher film budgets and box office revenue.
#
# <img src=https://i.imgur.com/kq7hrEh.png>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# # Read the Data

# %%
data = pd.read_csv('data/cost_revenue_dirty.csv')

# %% [markdown]
# # Explore and Clean the Data

# %% [markdown]
# Initial Dataset review:
# - How many rows and columns does the dataset contain?
# - Are there any NaN values present?
# - Are there any duplicate rows?
# - What are the data types of the columns?

# %% [markdown]
# ### Data Overview

# %%
data
# Out:
#       Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 0     5293     8/2/1915           The Birth of a Nation              $110,000
# 1     5140     5/9/1916                     Intolerance              $385,907
# 2     5230   12/24/1916    20,000 Leagues Under the Sea              $200,000
# 3     5299    9/17/1920  Over the Hill to the Poorhouse              $100,000
# 4     5222     1/1/1925                  The Big Parade              $245,000
# ...    ...          ...                             ...                   ...
# 5386  2950    10/8/2018                             Meg           $15,000,000
# 5387   126   12/18/2018                         Aquaman          $160,000,000
# 5388    96   12/31/2020                     Singularity          $175,000,000
# 5389  1119   12/31/2020          Hannibal the Conqueror           $50,000,000
# 5390  2517   12/31/2020  Story of Bonnie and Clyde, The           $20,000,000
#
# ...

# %% [markdown]
# ### Checking for NaN values

# %%
data.isna().values.sum()
# Out:
# 0

# %% [markdown]
# ### Checking for duplicates

# %%
data.duplicated().values.sum()
# Out:
# 0

# %% [markdown]
# ### Checking data types

# %%
data.dtypes
# Out:
# Rank                      int64
# Release_Date             object
# Movie_Title              object
# USD_Production_Budget    object
# USD_Worldwide_Gross      object
# USD_Domestic_Gross       object
# dtype: object

# %% [markdown]
# ### Data Type Conversions

# %% [markdown]
# Converting the `USD_Production_Budget`, `USD_Worldwide_Gross`, and `USD_Domestic_Gross` columns to a numeric format

# %%
# Removing commas and $ from values
chars_to_remove = [',', '$']
columns_to_clean = ['USD_Production_Budget', 
                    'USD_Worldwide_Gross',
                    'USD_Domestic_Gross']
 
for col in columns_to_clean:
    for char in chars_to_remove:
        # Replace each character with an empty string
        data[col] = data[col].astype(str).str.replace(char, "")
    # Convert column to a numeric data type
    data[col] = pd.to_numeric(data[col])

data
# Out:
# C:\Users\armed\AppData\Local\Temp\ipykernel_10440\330047073.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data[col] = data[col].astype(str).str.replace(char, "")
#       Rank Release_Date                     Movie_Title  \
# 0     5293     8/2/1915           The Birth of a Nation
# 1     5140     5/9/1916                     Intolerance
# 2     5230   12/24/1916    20,000 Leagues Under the Sea
# 3     5299    9/17/1920  Over the Hill to the Poorhouse
# 4     5222     1/1/1925                  The Big Parade
# ...    ...          ...                             ...
# 5386  2950    10/8/2018                             Meg
# 5387   126   12/18/2018                         Aquaman
# 5388    96   12/31/2020                     Singularity
# 5389  1119   12/31/2020          Hannibal the Conqueror
# ...

# %% [markdown]
# Converting the `Release_Date` column to a Pandas Datetime type.

# %%
data['Release_Date'] = pd.to_datetime(data['Release_Date'])
data
# Out:
#       Rank Release_Date                     Movie_Title  \
# 0     5293   1915-08-02           The Birth of a Nation
# 1     5140   1916-05-09                     Intolerance
# 2     5230   1916-12-24    20,000 Leagues Under the Sea
# 3     5299   1920-09-17  Over the Hill to the Poorhouse
# 4     5222   1925-01-01                  The Big Parade
# ...    ...          ...                             ...
# 5386  2950   2018-10-08                             Meg
# 5387   126   2018-12-18                         Aquaman
# 5388    96   2020-12-31                     Singularity
# 5389  1119   2020-12-31          Hannibal the Conqueror
# 5390  2517   2020-12-31  Story of Bonnie and Clyde, The
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 0                    110000             11000000            10000000
# 1                    385907                    0                   0
# 2                    200000              8000000             8000000
# ...

# %% [markdown]
# ### Confirming that the data types have changed

# %%
data.dtypes
# Out:
# Rank                              int64
# Release_Date             datetime64[ns]
# Movie_Title                      object
# USD_Production_Budget             int64
# USD_Worldwide_Gross               int64
# USD_Domestic_Gross                int64
# dtype: object

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# Further analysis:
#
# 1. What is the average production budget of the films in the data set?
# 2. What is the average worldwide gross revenue of films?
# 3. What were the minimums for worldwide and domestic revenue?
# 4. Are the bottom 25% of films actually profitable or do they lose money?
# 5. What are the highest production budget and highest worldwide gross revenue of any film?
# 6. How much revenue did the lowest and highest budget films make?

# %%
data.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# count 5,391.00               5,391.00             5,391.00            5,391.00
# mean  2,696.00          31,113,737.58        88,855,421.96       41,235,519.44
# std   1,556.39          40,523,796.88       168,457,757.00       66,029,346.27
# min       1.00               1,100.00                 0.00                0.00
# 25%   1,348.50           5,000,000.00         3,865,206.00        1,330,901.50
# 50%   2,696.00          17,000,000.00        27,450,453.00       17,192,205.00
# 75%   4,043.50          40,000,000.00        96,454,455.00       52,343,687.00
# max   5,391.00         425,000,000.00     2,783,918,982.00      936,662,225.00

# %% [markdown]
# # Investigating the Zero Revenue Films

# %% [markdown]
# Further review: How many films grossed $0 domestically (in the US)? What were the highest budget films that grossed nothing?

# %%
zero_domestic = data[data.USD_Domestic_Gross == 0]
print(f'Number of films that grossed $0 domestically {len(zero_domestic)}')
zero_domestic.sort_values('USD_Production_Budget', ascending=False)
# Out:
# Number of films that grossed $0 domestically 512
#       Rank Release_Date                         Movie_Title  \
# 5388    96   2020-12-31                         Singularity
# 5387   126   2018-12-18                             Aquaman
# 5384   321   2018-09-03                   A Wrinkle in Time
# 5385   366   2018-10-08                      Amusement Park
# 5090   556   2015-12-31  Don Gato, el inicio de la pandilla
# ...    ...          ...                                 ...
# 4787  5371   2014-12-31                Stories of Our Lives
# 3056  5374   2007-12-31                         Tin Can Man
# 4907  5381   2015-05-19                    Family Motocross
# 5006  5389   2015-09-29             Signed Sealed Delivered
# 5007  5390   2015-09-29                A Plague So Pleasant
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5388              175000000                    0                   0
# ...

# %% [markdown]
# How many films grossed $0 worldwide? What are the highest budget films that had no revenue internationally?

# %%
zero_worldwide = data[data.USD_Worldwide_Gross == 0]
print(f'Number of films that grossed $0 worldwide {len(zero_worldwide)}')
zero_worldwide.sort_values('USD_Production_Budget', ascending=False)
# Out:
# Number of films that grossed $0 worldwide 357
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 5388    96   2020-12-31              Singularity              175000000
# 5387   126   2018-12-18                  Aquaman              160000000
# 5384   321   2018-09-03        A Wrinkle in Time              103000000
# 5385   366   2018-10-08           Amusement Park              100000000
# 5058   880   2015-11-12         The Ridiculous 6               60000000
# ...    ...          ...                      ...                    ...
# 4787  5371   2014-12-31     Stories of Our Lives                  15000
# 3056  5374   2007-12-31              Tin Can Man                  12000
# 4907  5381   2015-05-19         Family Motocross                  10000
# 5006  5389   2015-09-29  Signed Sealed Delivered                   5000
# 5007  5390   2015-09-29     A Plague So Pleasant                   1400
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# ...

# %% [markdown]
# ### Filtering on Multiple Conditions

# %%
# Finding movies with both no domestic and worldwide gross
international_releases = data.loc[(data.USD_Domestic_Gross == 0) & 
                                  (data.USD_Worldwide_Gross != 0)]
international_releases
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
# ...    ...          ...                      ...                    ...
# 5340  1506   2017-04-14      Queen of the Desert               36000000
# 5348  2225   2017-05-05        Chāi dàn zhuānjiā               23000000
# 5360  4832   2017-07-03                Departure                1100000
# 5372  1856   2017-08-25                Ballerina               30000000
# 5374  4237   2017-08-25     Polina danser sa vie                4000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# ...

# %% [markdown]
# Using the [`.query()` function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) to accomplish the same thing. Creating a subset for international releases that had some worldwide gross revenue, but made zero revenue in the United States.

# %%
international_releases = data.query('USD_Domestic_Gross == 0 and USD_Worldwide_Gross != 0')
international_releases
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
# ...    ...          ...                      ...                    ...
# 5340  1506   2017-04-14      Queen of the Desert               36000000
# 5348  2225   2017-05-05        Chāi dàn zhuānjiā               23000000
# 5360  4832   2017-07-03                Departure                1100000
# 5372  1856   2017-08-25                Ballerina               30000000
# 5374  4237   2017-08-25     Polina danser sa vie                4000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# ...

# %% [markdown]
# ### Unreleased Films
#
# Further review:
#
# * Looking at which films were not released yet as of the time of data collection (May 1st, 2018).
# * How many films are included in the dataset that have not yet had a chance to be screened in the box office?
# * Creating another DataFrame called data_clean that does not include these films.

# %% [markdown]
# ### Date of Data Collection

# %%
scrape_date = pd.Timestamp('2018-5-1')

# %%
scrape_date
unreleased = data.query('Release_Date > @scrape_date')
unreleased
# Out:
#       Rank Release_Date                     Movie_Title  \
# 5384   321   2018-09-03               A Wrinkle in Time
# 5385   366   2018-10-08                  Amusement Park
# 5386  2950   2018-10-08                             Meg
# 5387   126   2018-12-18                         Aquaman
# 5388    96   2020-12-31                     Singularity
# 5389  1119   2020-12-31          Hannibal the Conqueror
# 5390  2517   2020-12-31  Story of Bonnie and Clyde, The
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5384              103000000                    0                   0
# 5385              100000000                    0                   0
# 5386               15000000                    0                   0
# 5387              160000000                    0                   0
# 5388              175000000                    0                   0
# 5389               50000000                    0                   0
# ...

# %%
data_clean = data.drop(unreleased.index)
data_clean
# Out:
#       Rank Release_Date                       Movie_Title  \
# 0     5293   1915-08-02             The Birth of a Nation
# 1     5140   1916-05-09                       Intolerance
# 2     5230   1916-12-24      20,000 Leagues Under the Sea
# 3     5299   1920-09-17    Over the Hill to the Poorhouse
# 4     5222   1925-01-01                    The Big Parade
# ...    ...          ...                               ...
# 5379  1295   2017-10-02            John Wick: Chapter Two
# 5380    70   2017-10-03                Kong: Skull Island
# 5381    94   2017-12-05  King Arthur: Legend of the Sword
# 5382  1254   2017-12-05                          Snatched
# 5383  2521   2017-12-31                The Thousand Miles
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 0                    110000             11000000            10000000
# 1                    385907                    0                   0
# ...

# %% [markdown]
# ### Films that Lost Money
#
# What is the percentage of films where the production costs exceeded the worldwide gross revenue?

# %%
no_profit_data = data_clean.query('USD_Production_Budget > USD_Worldwide_Gross')

# %%
f"The percentage of films that did not break even is {round(((no_profit_data.shape[0]/data_clean.shape[0])*100), 2)}"
# Out:
# 'The percentage of films that did not break even is 37.28'

# %% [markdown]
# # Seaborn for Data Visualization: Bubble Charts

# %%
plt.figure(figsize=(8,4), dpi=200)

# set styling on a single chart
with sns.axes_style('darkgrid'):
    ax = sns.scatterplot(data=data_clean,
                       x='USD_Production_Budget', 
                       y='USD_Worldwide_Gross',
                       hue='USD_Worldwide_Gross',
                       size='USD_Worldwide_Gross')

    ax.set(ylim=(0, 3000000000),
           xlim=(0, 450000000),
           ylabel='Revenue in $ billions',
           xlabel='Budget in $100 millions',
          title='Revenue vs. Budget - Bubble Chart')

plt.show()

# %% [markdown]
# ### Plotting Movie Releases over Time
#
# Creating a bubble chart

# %%
plt.figure(figsize=(8,4), dpi=200)

# set styling on a single chart
with sns.axes_style('darkgrid'):
    ax = sns.scatterplot(data=data_clean,
                       x='Release_Date', 
                       y='USD_Production_Budget',
                       hue='USD_Worldwide_Gross',
                       size='USD_Worldwide_Gross')

    ax.set(ylim=(0, 450000000),
           xlim=(data_clean['Release_Date'].min(), data_clean['Release_Date'].max()),
           xlabel='Year',
           ylabel='Budget in $100 millions',
          title='Revenue vs. Budget - Bubble Chart')

plt.show()

# %% [markdown]
# # Converting Years to Decades Trick
#
# Creating a column in `data_clean` that has the decade of the release.

# %%
datetime_data = data_clean['Release_Date']
datetime_data
# Out:
# 0      1915-08-02
# 1      1916-05-09
# 2      1916-12-24
# 3      1920-09-17
# 4      1925-01-01
#           ...
# 5379   2017-10-02
# 5380   2017-10-03
# 5381   2017-12-05
# 5382   2017-12-05
# 5383   2017-12-31
# Name: Release_Date, Length: 5384, dtype: datetime64[ns]

# %%
decades = [x.year//10*10 for x in datetime_data]
data_clean['Decade'] = decades
data_clean
# Out:
#       Rank Release_Date                       Movie_Title  \
# 0     5293   1915-08-02             The Birth of a Nation
# 1     5140   1916-05-09                       Intolerance
# 2     5230   1916-12-24      20,000 Leagues Under the Sea
# 3     5299   1920-09-17    Over the Hill to the Poorhouse
# 4     5222   1925-01-01                    The Big Parade
# ...    ...          ...                               ...
# 5379  1295   2017-10-02            John Wick: Chapter Two
# 5380    70   2017-10-03                Kong: Skull Island
# 5381    94   2017-12-05  King Arthur: Legend of the Sword
# 5382  1254   2017-12-05                          Snatched
# 5383  2521   2017-12-31                The Thousand Miles
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 0                    110000             11000000            10000000    1910
# 1                    385907                    0                   0    1910
# ...

# %% [markdown]
# ### Separate the "old" (before 1969) and "New" (1970s onwards) Films
#
# Creating two new DataFrames: `old_films` and `new_films`
# * `old_films` includes all the films before 1969 (up to and including 1969)
# * `new_films` includes all the films from 1970 onwards
# * Checking how many films were released prior to 1970
# * Checking what was the most expensive film made prior to 1970

# %%
old_films = data_clean.query('Decade < 1970')
old_films.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  \
# count   153.00                 153.00               153.00
# mean  4,274.77           4,611,297.65        30,419,634.38
# std     742.14           5,713,648.85        54,931,828.93
# min   1,253.00             100,000.00                 0.00
# 25%   3,973.00           1,250,000.00         5,273,000.00
# 50%   4,434.00           2,900,000.00        10,000,000.00
# 75%   4,785.00           5,000,000.00        33,208,099.00
# max   5,299.00          42,000,000.00       390,525,192.00
#
#        USD_Domestic_Gross   Decade
# count              153.00   153.00
# mean        22,389,473.87 1,949.15
# std         32,641,752.41    12.72
# min                  0.00 1,910.00
# 25%          5,000,000.00 1,940.00
# 50%         10,000,000.00 1,950.00
# 75%         28,350,000.00 1,960.00
# max        198,680,470.00 1,960.00

# %%
old_films.sort_values('USD_Production_Budget', ascending=False).head()
# Out:
#      Rank Release_Date                   Movie_Title  USD_Production_Budget  \
# 109  1253   1963-12-06                     Cleopatra               42000000
# 150  2175   1969-12-16                  Hello, Dolly               24000000
# 143  2465   1969-01-01                 Sweet Charity               20000000
# 118  2425   1965-02-15  The Greatest Story Ever Told               20000000
# 148  2375   1969-10-15              Paint Your Wagon               20000000
#
#      USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 109             71000000            57000000    1960
# 150             33208099            33208099    1960
# 143              8000000             8000000    1960
# 118             15473333            15473333    1960
# 148             31678778            31678778    1960

# %%
new_films = data_clean.query('Decade > 1970')
new_films.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  \
# count 5,122.00               5,122.00             5,122.00
# mean  2,627.78          32,303,670.64        91,101,526.25
# std   1,549.76          41,026,266.68       171,406,401.64
# min       1.00               1,100.00                 0.00
# 25%   1,288.25           5,500,000.00         3,618,183.25
# 50%   2,589.50          18,000,000.00        28,612,667.00
# 75%   3,938.75          40,000,000.00        99,003,897.75
# max   5,391.00         425,000,000.00     2,783,918,982.00
#
#        USD_Domestic_Gross   Decade
# count            5,122.00 5,122.00
# mean        41,726,699.21 2,000.83
# std         66,769,429.69     8.60
# min                  0.00 1,980.00
# 25%          1,186,720.00 2,000.00
# 50%         17,328,068.50 2,000.00
# 75%         53,301,948.50 2,010.00
# max        936,662,225.00 2,010.00

# %% [markdown]
# # Seaborn Regression Plots

# %%
plt.figure(figsize=(8,4), dpi=200)
with sns.axes_style("whitegrid"):
    ax = sns.regplot(data=old_films, 
            x='USD_Production_Budget', 
            y='USD_Worldwide_Gross',
            scatter_kws = {'alpha': 0.4},
            line_kws = {'color': 'black'})
    ax.set(xlim=(0),
           ylim=(0),
           title='Budget vs Worldwide Gross - Regression Plot')

# %% [markdown]
# Using Seaborn's `.regplot()` to show the scatter plot and linear regression line against the `new_films`.

# %%
plt.figure(figsize=(8,4), dpi=200)
with sns.axes_style("darkgrid"):
    ax = sns.regplot(data=new_films, 
            x='USD_Production_Budget', 
            y='USD_Worldwide_Gross',
            scatter_kws = {'alpha': 0.4,
                          'color': '#2f4b7c'},
            line_kws = {'color': '#ff7c43'})

ax.set(ylim=(0, new_films['USD_Worldwide_Gross'].max()),
           xlim=(new_films['USD_Production_Budget'].min(), new_films['USD_Production_Budget'].max()),
           xlabel='Budget in Hundred Millions',
           ylabel='Revenue in Billions', 
           title='Revenue(Billions) vs Budget (Hundred Millions) - Regression Plot')
# Out:
# [(0.0, 2783918982.0),
#  (1100.0, 425000000.0),
#  Text(0.5, 0, 'Budget in Hundred Millions'),
#  Text(0, 0.5, 'Revenue in Billions'),
#  Text(0.5, 1.0, 'Revenue(Billions) vs Budget (Hundred Millions) - Regression Plot')]

# %% [markdown]
# # Running Regression with scikit-learn
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$

# %%
regression = LinearRegression()
# Explanatory Variable(s) or Feature(s)
X = pd.DataFrame(new_films, columns=['USD_Production_Budget'])
 
# Response Variable or Target
y = pd.DataFrame(new_films, columns=['USD_Worldwide_Gross'])

# Finding the best-fit line
regression.fit(X, y)

# Theta zero
regression.intercept_
# Out:
# array([-10278584.79397975])

# %%
# Theta one
regression.coef_
# Out:
# array([[3.13834648]])

# %%
# R-squared
regression.score(X, y)
# Out:
# 0.564250171393927

# %% [markdown]
# Running a linear regression for the `old_films`. Calculating the intercept, slope and r-squared. How much of the variance in movie revenue does the linear model explain in this case?

# %%
old_regression = LinearRegression()
# Explanatory Variable(s) or Feature(s)
X_old = pd.DataFrame(old_films, columns=['USD_Production_Budget'])
 
# Response Variable or Target
y_old = pd.DataFrame(old_films, columns=['USD_Worldwide_Gross'])

# Finding the best-fit line
old_regression.fit(X_old, y_old)

# Theta zero
old_regression.intercept_
# Out:
# array([22821538.63508038])

# %%
# Theta one
old_regression.coef_
# Out:
# array([[1.64771314]])

# %%
# R-squared
old_regression.score(X_old, y_old)
# Out:
# 0.02937258620576877

# %% [markdown]
# # Using Model to Make a Prediction
#
# Linear Model has the following form:
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$
#
# Estimating how much global revenue the model estimates for a film with a budget of $350 million

# %%
# estimate = old_regression.intercept_ + old_regression.coef_ * 350000000
# estimate
estimate = old_regression.intercept_ + old_regression.coef_ * 350
f"Estimated global revenue for a film with a budget of $350 million is ${estimate} million"
# Out:
# 'Estimated global revenue for a film with a budget of $350 million is $[[22822115.33468078]] million'
